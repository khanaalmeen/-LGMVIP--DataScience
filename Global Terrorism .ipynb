# %% [markdown]
# # Exploratory Data Analysis (EDA) - Terrorism
#
# As a security/defense analyst , try to find out the hot zone of Terrorism.
#
# What all the security issues and insights you can derive by EDA.
#
# ### Submitted By - Aalmeen Khan

# %% [markdown]
# ### Importing all the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### Importing the dataset

# %%
data=pd.read_csv(r"C:\Users\aalme\OneDrive\Desktop\globalterrorismdb_0718dist.csv",encoding='latin1')

# %%
data.head(5)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
data.shape
# Out:
# (181691, 135)

# %%
data.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       5.000000      11.510046
# 50%         0.000000      98.000000       6.000000      31.467463
# 75%         0.000000     160.000000      10.000000      34.685087
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity  ...     ransomamt   ransomamtus  \
# count  1.771340e+05  181685.000000  ...  1.350000e+03  5.630000e+02
# mean  -4.586957e+02       1.451452  ...  3.172530e+06  5.784865e+05
# std    2.047790e+05       0.995430  ...  3.021157e+07  7.077924e+06
# min   -8.618590e+07       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%    4.545640e+00       1.000000  ...  0.000000e+00  0.000000e+00
# 50%    4.324651e+01       1.000000  ...  1.500000e+04  0.000000e+00
# 75%    6.871033e+01       1.000000  ...  4.000000e+05  0.000000e+00
# max    1.793667e+02       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  7.740000e+02    552.000000    10991.000000  10400.000000
# mean   7.179437e+05    240.378623        4.629242    -29.018269
# std    1.014392e+07   2940.967293        2.035360     65.720119
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2769.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       -4.543731      -4.464398       0.090010      -3.945952
# std         4.543547       4.637152       0.568457       4.691325
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# we will consider only these columns 
data= data[['iyear', 'imonth', 'iday','country_txt','region_txt',"success","city","attacktype1_txt","targtype1_txt",
       "gname","weaptype1_txt","nkill","nwound"]]
data
# Out:
#         iyear  imonth  iday         country_txt                   region_txt  \
# 0        1970       7     2  Dominican Republic  Central America & Caribbean
# 1        1970       0     0              Mexico                North America
# 2        1970       1     0         Philippines               Southeast Asia
# 3        1970       1     0              Greece               Western Europe
# 4        1970       1     0               Japan                    East Asia
# ...       ...     ...   ...                 ...                          ...
# 181686   2017      12    31             Somalia           Sub-Saharan Africa
# 181687   2017      12    31               Syria   Middle East & North Africa
# 181688   2017      12    31         Philippines               Southeast Asia
# 181689   2017      12    31               India                   South Asia
# 181690   2017      12    31         Philippines               Southeast Asia
#
#         success           city                 attacktype1_txt  \
# 0             1  Santo Domingo                   Assassination
# 1             1    Mexico city     Hostage Taking (Kidnapping)
# 2             1        Unknown                   Assassination
# 3             1         Athens               Bombing/Explosion
# 4             1        Fukouka  Facility/Infrastructure Attack
# ...         ...            ...                             ...
# 181686        1  Ceelka Geelow                   Armed Assault
# 181687        1         Jableh               Bombing/Explosion
# 181688        1       Kubentog  Facility/Infrastructure Attack
# 181689        0         Imphal               Bombing/Explosion
# 181690        0  Cotabato City               Bombing/Explosion
#
#                       targtype1_txt  \
# 0       Private Citizens & Property
# 1           Government (Diplomatic)
# 2               Journalists & Media
# 3           Government (Diplomatic)
# 4           Government (Diplomatic)
# ...                             ...
# 181686                     Military
# 181687                     Military
# 181688  Private Citizens & Property
# 181689         Government (General)
# 181690                      Unknown
#
#                                              gname weaptype1_txt  nkill  \
# 0                                           MANO-D       Unknown    1.0
# 1               23rd of September Communist League       Unknown    0.0
# 2                                          Unknown       Unknown    1.0
# 3                                          Unknown    Explosives    NaN
# 4                                          Unknown    Incendiary    NaN
# ...                                            ...           ...    ...
# 181686                                  Al-Shabaab      Firearms    1.0
# 181687                           Muslim extremists    Explosives    2.0
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)    Incendiary    0.0
# 181689                                     Unknown    Explosives    0.0
# 181690                                     Unknown    Explosives    0.0
#
#         nwound
# 0          0.0
# 1          0.0
# 2          0.0
# 3          NaN
# 4          NaN
# ...        ...
# 181686     2.0
# 181687     7.0
# 181688     0.0
# 181689     0.0
# 181690     0.0
#
# [181691 rows x 13 columns]

# %%
# filling the NaN values
data['nkill']=data['nkill'].fillna(0)
data['nwound']=data['nwound'].fillna(0)

# %%
# creating a new column casualty
data['casualty']=data['nkill']+data['nwound']

# %%
data.head(5)
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#    success           city                 attacktype1_txt  \
# 0        1  Santo Domingo                   Assassination
# 1        1    Mexico city     Hostage Taking (Kidnapping)
# 2        1        Unknown                   Assassination
# 3        1         Athens               Bombing/Explosion
# 4        1        Fukouka  Facility/Infrastructure Attack
#
#                  targtype1_txt                               gname  \
# 0  Private Citizens & Property                              MANO-D
# 1      Government (Diplomatic)  23rd of September Communist League
# 2          Journalists & Media                             Unknown
# 3      Government (Diplomatic)                             Unknown
# 4      Government (Diplomatic)                             Unknown
#
#   weaptype1_txt  nkill  nwound  casualty
# 0       Unknown    1.0     0.0       1.0
# 1       Unknown    0.0     0.0       0.0
# 2       Unknown    1.0     0.0       1.0
# 3    Explosives    0.0     0.0       0.0
# 4    Incendiary    0.0     0.0       0.0

# %%
# finding number of duplicate values
data.duplicated().sum()
# Out:
# 14267

# %%
# dropping the duplicate values
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Correlation between the variables

# %%
data.corr()
# Out:
#              iyear    imonth      iday   success     nkill    nwound  casualty
# iyear     1.000000 -0.001323  0.017724 -0.069702  0.014002  0.014678  0.016292
# imonth   -0.001323  1.000000  0.005055 -0.001641  0.003695  0.003012  0.003570
# iday      0.017724  0.005055  1.000000 -0.008522 -0.003873 -0.001217 -0.002100
# success  -0.069702 -0.001641 -0.008522  1.000000  0.051342  0.024031  0.034525
# nkill     0.014002  0.003695 -0.003873  0.051342  1.000000  0.443254  0.651457
# nwound    0.014678  0.003012 -0.001217  0.024031  0.443254  1.000000  0.968843
# casualty  0.016292  0.003570 -0.002100  0.034525  0.651457  0.968843  1.000000

# %% [markdown]
# ### Visualisation of Data

# %%
#Number of attacks each year

Number_of_Attacks=data["iyear"].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={"index":"Year","iyear":"Attacks"}).set_index("Year")
Number_of_Attacks.head()
# Out:
#       Attacks
# Year
# 1970      612
# 1971      449
# 1972      488
# 1973      462
# 1974      532

# %%
plt.figure(figsize=(25,15))
plt.title('Attacks',fontweight='bold',size=20)
sns.countplot(x=data.iyear,palette="YlOrRd")
plt.xlabel("Year",fontsize=20,fontweight="bold")
plt.ylabel("Number of Attacks",fontsize=20,fontweight="bold")
plt.xticks(rotation=90,fontweight="bold",size=15)
plt.yticks(fontweight="bold",size=15)
plt.show()

# %%
#Number of Casualty in each year

Number_of_Casualty=data[["iyear","casualty"]].groupby("iyear").sum()
Number_of_Casualty.head()
# Out:
#        casualty
# iyear
# 1970      385.0
# 1971      254.0
# 1972      957.0
# 1973      861.0
# 1974     1398.0

# %%
Number_of_Casualty.plot(kind="bar",color="green",figsize=(12,6),fontsize=13)
plt.title("Casualty",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Casualty",fontsize=13)
plt.show()

# %%
data["region_txt"].value_counts()
# Out:
# Middle East & North Africa     47418
# South Asia                     42744
# Sub-Saharan Africa             16766
# South America                  15767
# Western Europe                 14581
# Southeast Asia                 11797
# Central America & Caribbean     8726
# Eastern Europe                  4931
# North America                   3200
# East Asia                        677
# Central Asia                     548
# Australasia & Oceania            269
# Name: region_txt, dtype: int64

# %%
plt.figure(figsize=(25,15))
plt.title('Total number of attacks Region-wise',fontweight='bold',size=20)
sns.countplot(x=data.region_txt)
plt.xlabel("Region-wise",fontsize=20,fontweight="bold")
plt.ylabel("Number of Attacks",fontsize=20,fontweight="bold")
plt.xticks(rotation=90,fontweight="bold",size=15)
plt.yticks(fontweight="bold",size=15)
plt.show()

# %% [markdown]
# - Middle East and North Africa followed by South Asia are the hot zones for terrorism.
# - Central Asia has least number of Terrorist Attacks

# %%
region=pd.crosstab(data.iyear,data.region_txt).plot(kind='area',figsize=(20,10))
plt.title('Terrorism by region in each year')
plt.ylabel('Attacks')
plt.show()

# %%
data["country_txt"].value_counts()[:20]
# Out:
# Iraq              22868
# Pakistan          13522
# Afghanistan       12291
# India             11426
# Colombia           7288
# Philippines        6700
# United Kingdom     4837
# Peru               4722
# El Salvador        4109
# Somalia            4041
# Turkey             3936
# Nigeria            3720
# Thailand           3573
# Yemen              3194
# Spain              2959
# Sri Lanka          2888
# Algeria            2713
# United States      2635
# Lebanon            2399
# Egypt              2346
# Name: country_txt, dtype: int64

# %%
plt.figure(figsize=(25,15))
plt.title('Total number of attacks Country-wise',fontweight='bold',size=20)
sns.barplot(x=data['country_txt'].value_counts()[:20].index,y=data['country_txt'].value_counts()[:20].values)
plt.xlabel("Country-wise",fontsize=20,fontweight="bold")
plt.ylabel("Number of Attacks",fontsize=20,fontweight="bold")
plt.xticks(rotation=90,fontweight="bold",size=15)
plt.yticks(fontweight="bold",size=15)
plt.show()

# %% [markdown]
# - Iraq has most number of terrorist attacks
# - Egypt has the least number of terrorist attacks

# %%
# Terrorism attacks over years

data['iyear'].plot.hist() 
plt.xlabel('year')
plt.ylabel('number of attacks')
plt.title('terrorism attacks over years')
# Out:
# Text(0.5, 1.0, 'terrorism attacks over years')

# %%
sns.countplot(x='success',data=data)
plt.xlabel('sucess status')
plt.ylabel('No.of attacks')
plt.title('No. of success and failure of terrorism attacks')
# Out:
# Text(0.5, 1.0, 'No. of success and failure of terrorism attacks')

# %%
data["attacktype1_txt"].value_counts()
# Out:
# Bombing/Explosion                      79050
# Armed Assault                          40859
# Assassination                          18632
# Hostage Taking (Kidnapping)            10828
# Facility/Infrastructure Attack          8794
# Unknown                                 6789
# Unarmed Assault                          912
# Hostage Taking (Barricade Incident)      911
# Hijacking                                649
# Name: attacktype1_txt, dtype: int64

# %%
plt.figure(figsize=(25,15))
plt.title('Attack Type',fontweight='bold',size=20)
sns.countplot(x=data.attacktype1_txt)
plt.xlabel("Attach Type",fontsize=20,fontweight="bold")
plt.ylabel("Number of Attacks",fontsize=20,fontweight="bold")
plt.xticks(rotation=90,fontweight="bold",size=15)
plt.yticks(fontweight="bold",size=15)
plt.show()

# %% [markdown]
# Bombing/Explosion follwed by Armed Assault and Assassination are the most common Attack type.

# %%
data["targtype1_txt"].value_counts()
# Out:
# Private Citizens & Property       40452
# Military                          27191
# Police                            23521
# Government (General)              19901
# Business                          17771
# Transportation                     5980
# Unknown                            4947
# Religious Figures/Institutions     4183
# Educational Institution            4004
# Utilities                          3939
# Government (Diplomatic)            3409
# Terrorists/Non-State Militia       2975
# Journalists & Media                2813
# Violent Political Party            1770
# Airports & Aircraft                1305
# NGO                                 948
# Telecommunication                   882
# Tourists                            427
# Maritime                            337
# Food or Water Supply                294
# Abortion Related                    244
# Other                               131
# Name: targtype1_txt, dtype: int64

# %%
plt.figure(figsize=(25,15))
plt.title('Target Type',fontweight='bold',size=20)
sns.countplot(x=data.targtype1_txt)
plt.xlabel("Target Type",fontsize=20,fontweight="bold")
plt.ylabel("Number of Attacks",fontsize=20,fontweight="bold")
plt.xticks(rotation=90,fontweight="bold",size=15)
plt.yticks(fontweight="bold",size=15)
plt.show()

# %% [markdown]
# Most targeted areas are Private Citizens and property, Military and police

# %%
data['gname'].value_counts()[:20]
# Out:
# Unknown                                             77733
# Taliban                                              7208
# Islamic State of Iraq and the Levant (ISIL)          4995
# Shining Path (SL)                                    3535
# Al-Shabaab                                           3189
# New People's Army (NPA)                              2677
# Farabundo Marti National Liberation Front (FMLN)     2427
# Irish Republican Army (IRA)                          2368
# Revolutionary Armed Forces of Colombia (FARC)        2329
# Boko Haram                                           2300
# Kurdistan Workers' Party (PKK)                       2189
# Basque Fatherland and Freedom (ETA)                  1837
# Communist Party of India - Maoist (CPI-Maoist)       1829
# Maoists                                              1591
# Liberation Tigers of Tamil Eelam (LTTE)              1564
# National Liberation Army of Colombia (ELN)           1371
# Tehrik-i-Taliban Pakistan (TTP)                      1307
# Palestinians                                         1097
# Al-Qaida in the Arabian Peninsula (AQAP)              999
# Houthi extremists (Ansar Allah)                       968
# Name: gname, dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.title('Total number of attacks Group-wise',fontweight='bold',size=20)
sns.barplot(x=data['gname'].value_counts()[:20].index,y=data['gname'].value_counts()[:20].values)
plt.xlabel("Country",fontsize=10,fontweight="bold")
plt.ylabel("Number of Attacks",fontsize=20,fontweight="bold")
plt.xticks(rotation=90,fontweight="bold",size=15)
plt.yticks(fontweight="bold",size=15)
plt.show()

# %% [markdown]
# From the above data Unknown groups,Taliban and ISIL are the major terrorist groups.

# %%
# Top 5 cities with highest terrorism attacks.

data['city'].value_counts().nlargest(6)
# Out:
# Unknown    7795
# Baghdad    7327
# Karachi    2114
# Mosul      2027
# Belfast    1935
# Lima       1520
# Name: city, dtype: int64

# %%
data['city'].value_counts().nlargest(6).plot(kind='bar', figsize=(10,5),color=['purple'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Top five cities with highest number of attacks are Baghdad,Karachi,Mosul,Belfast and Lima.

# %% [markdown]
# Conclusion
#
# The insights gathered from the dataset includes:
#
# -Number of terrorist attacks increases rapidly after 2010.
# -Out of total terrorism attacks, very few attacks failed and almost all the terrorism attacks were successful.
# -Top five cities with highest number of attacks are Baghdad,Karachi,Mosul,Belfast and Lima.
# -Compare to all the other countries,number of terrorist attacks in Iraq is very high, followed by Pakistan, Afganistan, India ans so on.
# -Most targeted areas are private citizens and property , police and so on.
